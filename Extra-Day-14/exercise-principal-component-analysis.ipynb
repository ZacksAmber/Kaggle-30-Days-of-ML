# %% [markdown]
# **This notebook is an exercise in the [Feature Engineering](https://www.kaggle.com/learn/feature-engineering) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/principal-component-analysis).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll work through several applications of PCA to the [*Ames*](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data) dataset.

# %% [markdown]
# Run this cell to set everything up!

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.feature_engineering_new.ex5 import *

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)


def apply_pca(X, standardize=True):
    # Standardize
    if standardize:
        X = (X - X.mean(axis=0)) / X.std(axis=0)
    # Create principal components
    pca = PCA()
    X_pca = pca.fit_transform(X)
    # Convert to dataframe
    component_names = [f"PC{i+1}" for i in range(X_pca.shape[1])]
    X_pca = pd.DataFrame(X_pca, columns=component_names)
    # Create loadings
    loadings = pd.DataFrame(
        pca.components_.T,  # transpose the matrix of loadings
        columns=component_names,  # so the columns are the principal components
        index=X.columns,  # and the rows are the original features
    )
    return pca, X_pca, loadings


def plot_variance(pca, width=8, dpi=100):
    # Create figure
    fig, axs = plt.subplots(1, 2)
    n = pca.n_components_
    grid = np.arange(1, n + 1)
    # Explained variance
    evr = pca.explained_variance_ratio_
    axs[0].bar(grid, evr)
    axs[0].set(
        xlabel="Component", title="% Explained Variance", ylim=(0.0, 1.0)
    )
    # Cumulative Variance
    cv = np.cumsum(evr)
    axs[1].plot(np.r_[0, grid], np.r_[0, cv], "o-")
    axs[1].set(
        xlabel="Component", title="% Cumulative Variance", ylim=(0.0, 1.0)
    )
    # Set up figure
    fig.set(figwidth=8, dpi=100)
    return axs


def make_mi_scores(X, y):
    X = X.copy()
    for colname in X.select_dtypes(["object", "category"]):
        X[colname], _ = X[colname].factorize()
    # All discrete features should now have integer dtypes
    discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features, random_state=0)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores


def score_dataset(X, y, model=XGBRegressor()):
    # Label encoding for categoricals
    for colname in X.select_dtypes(["category", "object"]):
        X[colname], _ = X[colname].factorize()
    # Metric for Housing competition is RMSLE (Root Mean Squared Log Error)
    score = cross_val_score(
        model, X, y, cv=5, scoring="neg_mean_squared_log_error",
    )
    score = -1 * score.mean()
    score = np.sqrt(score)
    return score


df = pd.read_csv("../input/fe-course-data/ames.csv")

# %% [markdown]
# Let's choose a few features that are highly correlated with our target, `SalePrice`.

# %%
features = [
    "GarageArea",
    "YearRemodAdd",
    "TotalBsmtSF",
    "GrLivArea",
]

print("Correlation with SalePrice:\n")
print(df[features].corrwith(df.SalePrice))
# Out:
# Correlation with SalePrice:
#
# GarageArea      0.640138
# YearRemodAdd    0.532974
# TotalBsmtSF     0.632529
# GrLivArea       0.706780
# dtype: float64

# %% [markdown]
# We'll rely on PCA to untangle the correlational structure of these features and suggest relationships that might be usefully modeled with new features.
#
# Run this cell to apply PCA and extract the loadings.

# %%
X = df.copy()
y = X.pop("SalePrice")
X = X.loc[:, features]

# `apply_pca`, defined above, reproduces the code from the tutorial
pca, X_pca, loadings = apply_pca(X)
print(loadings)
# Out:
#                    PC1       PC2       PC3       PC4
# GarageArea    0.541229  0.102375 -0.038470  0.833733
# YearRemodAdd  0.427077 -0.886612 -0.049062 -0.170639
# TotalBsmtSF   0.510076  0.360778 -0.666836 -0.406192
# GrLivArea     0.514294  0.270700  0.742592 -0.332837

# %%
features_mi_scores = pd.DataFrame(make_mi_scores(X, y))

features_mi_scores.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_fc42a_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_fc42a_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.1%, transparent 84.1%);
#         }#T_fc42a_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
#         }#T_fc42a_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.5%, transparent 63.5%);
#         }</style><table id="T_fc42a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI Scores</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc42a_level0_row0" class="row_heading level0 row0" >GrLivArea</th>
#                         <td id="T_fc42a_row0_col0" class="data row0 col0" >0.497836</td>
#             </tr>
#             <tr>
#                         <th id="T_fc42a_level0_row1" class="row_heading level0 row1" >GarageArea</th>
#                         <td id="T_fc42a_row1_col0" class="data row1 col0" >0.418882</td>
#             </tr>
#             <tr>
#                         <th id="T_fc42a_level0_row2" class="row_heading level0 row2" >TotalBsmtSF</th>
#                         <td id="T_fc42a_row2_col0" class="data row2 col0" >0.392234</td>
#             </tr>
#             <tr>
#                         <th id="T_fc42a_level0_row3" class="row_heading level0 row3" >YearRemodAdd</th>
#                         <td id="T_fc42a_row3_col0" class="data row3 col0" >0.316050</td>
#             </tr>
#     </tbody></table>

# %%
pca_mi_scores = pd.DataFrame(make_mi_scores(X_pca, y))

pca_mi_scores.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_a4396_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_a4396_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.1%, transparent 39.1%);
#         }#T_a4396_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.1%, transparent 30.1%);
#         }#T_a4396_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.1%, transparent 10.1%);
#         }</style><table id="T_a4396_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI Scores</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4396_level0_row0" class="row_heading level0 row0" >PC1</th>
#                         <td id="T_a4396_row0_col0" class="data row0 col0" >0.873029</td>
#             </tr>
#             <tr>
#                         <th id="T_a4396_level0_row1" class="row_heading level0 row1" >PC3</th>
#                         <td id="T_a4396_row1_col0" class="data row1 col0" >0.341337</td>
#             </tr>
#             <tr>
#                         <th id="T_a4396_level0_row2" class="row_heading level0 row2" >PC2</th>
#                         <td id="T_a4396_row2_col0" class="data row2 col0" >0.262388</td>
#             </tr>
#             <tr>
#                         <th id="T_a4396_level0_row3" class="row_heading level0 row3" >PC4</th>
#                         <td id="T_a4396_row3_col0" class="data row3 col0" >0.087857</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # 1) Interpret Component Loadings
#
# Look at the loadings for components `PC1` and `PC3`. Can you think of a description of what kind of contrast each component has captured? After you've thought about it, run the next cell for a solution.

# %%
# View the solution (Run this cell to receive credit!)
q_1.check()
# Out:
# Correct:
#
# The first component, `PC1`, seems to be a kind of "size" component, similar to what we saw in the tutorial: all of the features have the same sign (positive), indicating that this component is describing a contrast between houses having large values and houses having small values for these features.
#
# The interpretation of the third component `PC3` is a little trickier. The features `GarageArea` and `YearRemodAdd` both have near-zero loadings, so let's ignore those. This component is mostly about `TotalBsmtSF` and `GrLivArea`. It describes a contrast between houses with a lot of living area but small (or non-existant) basements, and the opposite: small houses with large basements.

# %% [markdown]
# -------------------------------------------------------------------------------
#
# Your goal in this question is to use the results of PCA to discover one or more new features that improve the performance of your model. One option is to create features inspired by the loadings, like we did in the tutorial. Another option is to use the components themselves as features (that is, add one or more columns of `X_pca` to `X`).
#
# # 2) Create New Features
#
# Add one or more new features to the dataset `X`. For a correct solution, get a validation score below 0.140 RMSLE. (If you get stuck, feel free to use the `hint` below!)

# %%
X = df.copy()
y = X.pop("SalePrice")

# YOUR CODE HERE: Add new features to X.
X = X.join(X_pca)

score = score_dataset(X, y)
print("Original score: 0.14284 RMSLE")
print("Creat New Features: 0.13361 RMSLE")
print("Join PCA: 0.13707 RMSLE")
print(f"Your Scores: {score:.5f} RMSLE")
# Out:
# Original score: 0.14284 RMSLE
# Creat New Features: 0.13361 RMSLE
# Join PCA: 0.13707 RMSLE
# Your Scores: 0.13707 RMSLE

# %%
mi_scores = pd.DataFrame(make_mi_scores(X, y))

mi_scores.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_34b71_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_34b71_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 67.8%, transparent 67.8%);
#         }#T_34b71_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 65.1%, transparent 65.1%);
#         }#T_34b71_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 56.5%, transparent 56.5%);
#         }#T_34b71_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.9%, transparent 49.9%);
#         }#T_34b71_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.8%, transparent 47.8%);
#         }#T_34b71_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 45.0%, transparent 45.0%);
#         }#T_34b71_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 44.7%, transparent 44.7%);
#         }#T_34b71_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 42.3%, transparent 42.3%);
#         }#T_34b71_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 42.2%, transparent 42.2%);
#         }#T_34b71_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.0%, transparent 39.0%);
#         }#T_34b71_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 37.2%, transparent 37.2%);
#         }#T_34b71_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 37.0%, transparent 37.0%);
#         }#T_34b71_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 35.7%, transparent 35.7%);
#         }#T_34b71_row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 33.6%, transparent 33.6%);
#         }#T_34b71_row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 32.0%, transparent 32.0%);
#         }#T_34b71_row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.3%, transparent 30.3%);
#         }#T_34b71_row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 29.9%, transparent 29.9%);
#         }#T_34b71_row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 27.3%, transparent 27.3%);
#         }#T_34b71_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.8%, transparent 26.8%);
#         }#T_34b71_row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.2%, transparent 26.2%);
#         }#T_34b71_row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.5%, transparent 25.5%);
#         }#T_34b71_row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 23.7%, transparent 23.7%);
#         }#T_34b71_row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.5%, transparent 22.5%);
#         }#T_34b71_row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.4%, transparent 22.4%);
#         }#T_34b71_row25_col0,#T_34b71_row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.9%, transparent 20.9%);
#         }#T_34b71_row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.3%, transparent 20.3%);
#         }#T_34b71_row28_col0,#T_34b71_row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.2%, transparent 20.2%);
#         }#T_34b71_row30_col0,#T_34b71_row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.1%, transparent 20.1%);
#         }#T_34b71_row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.2%, transparent 19.2%);
#         }#T_34b71_row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 15.0%, transparent 15.0%);
#         }#T_34b71_row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 14.9%, transparent 14.9%);
#         }#T_34b71_row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 14.0%, transparent 14.0%);
#         }#T_34b71_row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.3%, transparent 13.3%);
#         }#T_34b71_row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.9%, transparent 11.9%);
#         }#T_34b71_row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.8%, transparent 11.8%);
#         }#T_34b71_row39_col0,#T_34b71_row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.6%, transparent 10.6%);
#         }#T_34b71_row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.5%, transparent 10.5%);
#         }#T_34b71_row42_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.4%, transparent 10.4%);
#         }#T_34b71_row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.3%, transparent 10.3%);
#         }#T_34b71_row44_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.2%, transparent 10.2%);
#         }#T_34b71_row45_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.5%, transparent 8.5%);
#         }#T_34b71_row46_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.4%, transparent 8.4%);
#         }#T_34b71_row47_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.2%, transparent 8.2%);
#         }#T_34b71_row48_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.0%, transparent 8.0%);
#         }#T_34b71_row49_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.2%, transparent 6.2%);
#         }#T_34b71_row50_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.1%, transparent 6.1%);
#         }#T_34b71_row51_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.0%, transparent 6.0%);

# %%
X = df.copy()
y = X.pop("SalePrice")

# YOUR CODE HERE: Add new features to X.
X["Feature1"] = X.GrLivArea + X.TotalBsmtSF
X["Feature2"] = X.YearRemodAdd * X.TotalBsmtSF

score = score_dataset(X, y)
print("Original score: 0.14284 RMSLE")
print("Creat New Features: 0.13361 RMSLE")
print("Join PCA: 0.13707 RMSLE")
print(f"Your Scores: {score:.5f} RMSLE")
# Out:
# Original score: 0.14284 RMSLE
# Creat New Features: 0.13361 RMSLE
# Join PCA: 0.13707 RMSLE
# Your Scores: 0.13361 RMSLE

# %%
mi_scores = pd.DataFrame(make_mi_scores(X, y))

mi_scores.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_dead5_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_dead5_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 89.6%, transparent 89.6%);
#         }#T_dead5_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 87.9%, transparent 87.9%);
#         }#T_dead5_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.1%, transparent 75.1%);
#         }#T_dead5_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 66.3%, transparent 66.3%);
#         }#T_dead5_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 62.6%, transparent 62.6%);
#         }#T_dead5_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 60.8%, transparent 60.8%);
#         }#T_dead5_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.5%, transparent 59.5%);
#         }#T_dead5_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 58.3%, transparent 58.3%);
#         }#T_dead5_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 56.5%, transparent 56.5%);
#         }#T_dead5_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 55.9%, transparent 55.9%);
#         }#T_dead5_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.5%, transparent 49.5%);
#         }#T_dead5_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.2%, transparent 49.2%);
#         }#T_dead5_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 48.1%, transparent 48.1%);
#         }#T_dead5_row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 43.7%, transparent 43.7%);
#         }#T_dead5_row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 40.9%, transparent 40.9%);
#         }#T_dead5_row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 38.7%, transparent 38.7%);
#         }#T_dead5_row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 35.6%, transparent 35.6%);
#         }#T_dead5_row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 34.9%, transparent 34.9%);
#         }#T_dead5_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 34.6%, transparent 34.6%);
#         }#T_dead5_row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 34.3%, transparent 34.3%);
#         }#T_dead5_row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.8%, transparent 30.8%);
#         }#T_dead5_row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 29.9%, transparent 29.9%);
#         }#T_dead5_row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 27.3%, transparent 27.3%);
#         }#T_dead5_row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 27.2%, transparent 27.2%);
#         }#T_dead5_row25_col0,#T_dead5_row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.7%, transparent 26.7%);
#         }#T_dead5_row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.4%, transparent 26.4%);
#         }#T_dead5_row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.9%, transparent 25.9%);
#         }#T_dead5_row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.8%, transparent 25.8%);
#         }#T_dead5_row30_col0,#T_dead5_row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.3%, transparent 25.3%);
#         }#T_dead5_row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.8%, transparent 19.8%);
#         }#T_dead5_row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.0%, transparent 18.0%);
#         }#T_dead5_row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 17.7%, transparent 17.7%);
#         }#T_dead5_row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 17.1%, transparent 17.1%);
#         }#T_dead5_row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 16.7%, transparent 16.7%);
#         }#T_dead5_row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 16.3%, transparent 16.3%);
#         }#T_dead5_row38_col0,#T_dead5_row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 14.1%, transparent 14.1%);
#         }#T_dead5_row40_col0,#T_dead5_row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.6%, transparent 13.6%);
#         }#T_dead5_row42_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 12.9%, transparent 12.9%);
#         }#T_dead5_row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.4%, transparent 11.4%);
#         }#T_dead5_row44_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.1%, transparent 11.1%);
#         }#T_dead5_row45_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.9%, transparent 10.9%);
#         }#T_dead5_row46_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.9%, transparent 9.9%);
#         }#T_dead5_row47_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.5%, transparent 8.5%);
#         }#T_dead5_row48_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.1%, transparent 8.1%);
#         }#T_dead5_row49_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.9%, transparent 7.9%);
#         }#T_dead5_row50_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.7%, transparent 7.7%);
#         }#T_dead5_row51_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.2%, transparent 7.2%);

# %%
# Check your answer
q_2.check()
# Out:
# Correct:
#
# Here are two possible solutions, though you might have been able to find others.
# ```python
# # Solution 1: Inspired by loadings
# X = df.copy()
# y = X.pop("SalePrice")
#
# X["Feature1"] = X.GrLivArea + X.TotalBsmtSF
# X["Feature2"] = X.YearRemodAdd * X.TotalBsmtSF
#
# score = score_dataset(X, y)
# print(f"Your score: {score:.5f} RMSLE")
#
#
# # Solution 2: Uses components
# X = df.copy()
# y = X.pop("SalePrice")
#
# X = X.join(X_pca)
# score = score_dataset(X, y)
# print(f"Your score: {score:.5f} RMSLE")
# ```

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# -------------------------------------------------------------------------------
#
# The next question explores a way you can use PCA to detect outliers in the dataset (meaning, data points that are unusually extreme in some way). Outliers can have a detrimental effect on model performance, so it's good to be aware of them in case you need to take corrective action. PCA in particular can show you anomalous *variation* which might not be apparent from the original features: neither small houses nor houses with large basements are unusual, but it is unusual for small houses to have large basements. That's the kind of thing a principal component can show you.
#
# Run the next cell to show distribution plots for each of the principal components you created above.

# %%
X_pca.melt()
# Out:
#       variable     value
# 0          PC1 -0.165346
# 1          PC1 -0.639050
# 2          PC1 -0.794227
# 3          PC1  1.636658
# 4          PC1  0.293648
# ...        ...       ...
# 11715      PC4  0.820547
# 11716      PC4  0.620322
# 11717      PC4 -1.417521
# 11718      PC4 -0.374198
# 11719      PC4  0.328966
#
# [11720 rows x 2 columns]

# %%
sns.catplot(
    y="value",
    col="variable",
    data=X_pca.melt(),
    kind='boxen',
    sharey=False,
    col_wrap=2,
);

# %% [markdown]
# As you can see, in each of the components there are several points lying at the extreme ends of the distributions -- outliers, that is.
#
# Now run the next cell to see those houses that sit at the extremes of a component:

# %%
# You can change PC1 to PC2, PC3, or PC4
component = "PC1"

idx = X_pca[component].sort_values(ascending=False).index
df.loc[idx, ["SalePrice", "Neighborhood", "SaleCondition"] + features]
# Out:
#       SalePrice            Neighborhood SaleCondition  GarageArea  \
# 1498     160000                 Edwards       Partial      1418.0
# 2180     183850                 Edwards       Partial      1154.0
# 2181     184750                 Edwards       Partial       884.0
# 1760     745000              Northridge       Abnorml       813.0
# 1767     755000              Northridge        Normal       832.0
# ...         ...                     ...           ...         ...
# 662       59000                Old_Town        Normal         0.0
# 2679      80500               Brookside        Normal         0.0
# 2879      51689  Iowa_DOT_and_Rail_Road       Abnorml         0.0
# 780       63900                  Sawyer        Normal         0.0
# 1901      39300               Brookside        Normal         0.0
#
#       YearRemodAdd  TotalBsmtSF  GrLivArea
# 1498          2008       6110.0     5642.0
# 2180          2009       5095.0     5095.0
# 2181          2008       3138.0     4676.0
# 1760          1996       2396.0     4476.0
# 1767          1995       2444.0     4316.0
# ...            ...          ...        ...
# 662           1950        416.0      599.0
# 2679          1950          0.0      912.0
# 2879          1950          0.0      729.0
# 780           1950          0.0      660.0
# 1901          1950          0.0      334.0
#
# [2930 rows x 7 columns]

# %% [markdown]
# # 3) Outlier Detection
#
# Do you notice any patterns in the extreme values? Does it seem like the outliers are coming from some special subset of the data?
#
# After you've thought about your answer, run the next cell for the solution and some discussion.

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Notice that there are several dwellings listed as `Partial` sales in the `Edwards` neighborhood that stand out. A partial sale is what occurs when there are multiple owners of a property and one or more of them sell their "partial" ownership of the property.
#
# These kinds of sales are often happen during the settlement of a family estate or the dissolution of a business and aren't advertised publicly. If you were trying to predict the value of a house on the open market, you would probably be justified in removing sales like these from your dataset -- they are truly outliers.

# %% [markdown]
# # Keep Going #
#
# [**Apply target encoding**](https://www.kaggle.com/ryanholbrook/target-encoding) to give a boost to categorical features.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/221677) to chat with other Learners.*
